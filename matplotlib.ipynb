# %% [markdown]
# <a href="https://colab.research.google.com/github/Swathi-212002/AI_ML_Avanthi_Swathi/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#line chart
x=[1,2,3]
y=[4,5,6]
plt.plot(x,y)

# %%
#plt.xticks([2,4,6,8,10,12])
#plt.yticks([3,6,9,12,15,16])
x=[2,4,6,8,10,12]
y=[3,6,9,12,15,16]
plt.title('My First Graph',fontdict={'fontsize':10})
plt.xlabel('X coordinates')
plt.ylabel('Y coordinates')
plt.plot(x,y)
