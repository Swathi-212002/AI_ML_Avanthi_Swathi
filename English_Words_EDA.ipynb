# %% [markdown]
# <a href="https://colab.research.google.com/github/Swathi-212002/AI_ML_Avanthi_Swathi/blob/main/English_Words_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Pandas library

# %%
import pandas as pd

# %% [markdown]
# Read the txt file into a dataframe

# %%
df =pd.read_csv('/content/unix-words.txt')
df
# Out:
#                  A
# 0                a
# 1               aa
# 2              aal
# 3            aalii
# 4              aam
# ...            ...
# 235880      zythem
# 235881      Zythia
# 235882      zythum
# 235883     Zyzomys
# 235884  Zyzzogeton
#
# [235885 rows x 1 columns]

# %% [markdown]
# Display the first 10 rows of the dataframe

# %%
df.head(10)
# Out:
#           A
# 0         a
# 1        aa
# 2       aal
# 3     aalii
# 4       aam
# 5      Aani
# 6  aardvark
# 7  aardwolf
# 8     Aaron
# 9   Aaronic

# %% [markdown]
# Change the column name 'A' to the words

# %%
df = df.rename(columns={'A':'Names'})

# %%
df
# Out:
#              Names
# 0                a
# 1               aa
# 2              aal
# 3            aalii
# 4              aam
# ...            ...
# 235880      zythem
# 235881      Zythia
# 235882      zythum
# 235883     Zyzomys
# 235884  Zyzzogeton
#
# [235885 rows x 1 columns]

# %% [markdown]
# Add character count of each word as another column in the dataframe

# %%
df['Names']=df['Names'].fillna('')
df['Character Count']=df['Names'].apply(len)
df
# Out:
#              Names  Character Count
# 0                a                1
# 1               aa                2
# 2              aal                3
# 3            aalii                5
# 4              aam                3
# ...            ...              ...
# 235880      zythem                6
# 235881      Zythia                6
# 235882      zythum                6
# 235883     Zyzomys                7
# 235884  Zyzzogeton               10
#
# [235885 rows x 2 columns]

# %%
df
# Out:
#              Names  Character Count
# 0                a                1
# 1               aa                2
# 2              aal                3
# 3            aalii                5
# 4              aam                3
# ...            ...              ...
# 235880      zythem                6
# 235881      Zythia                6
# 235882      zythum                6
# 235883     Zyzomys                7
# 235884  Zyzzogeton               10
#
# [235885 rows x 2 columns]

# %% [markdown]
# Add a column called value which is the sum of the numerical positions of the alphabets in the word
# (Ex: aah = 1 + 1 + 8 = 10)

# %%
def summing(word):
  sum=0
  word.lower()
  for char in word:
    position=ord(char)-96
    sum+=position
  return sum

df['Values']=df['Names'].apply(summing)

# %%
df
# Out:
#              Names  Character Count  Values
# 0                a                1       1
# 1               aa                2       2
# 2              aal                3      14
# 3            aalii                5      32
# 4              aam                3      15
# ...            ...              ...     ...
# 235880      zythem                6      97
# 235881      Zythia                6      57
# 235882      zythum                6     113
# 235883     Zyzomys                7     117
# 235884  Zyzzogeton               10     147
#
# [235885 rows x 3 columns]

# %% [markdown]
# Write a command to find the number of items in the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235885 entries, 0 to 235884
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Names            235885 non-null  object
#  1   Character Count  235885 non-null  int64
#  2   Values           235885 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 5.4+ MB

# %%
df.size
# Out:
# 707655

# %% [markdown]
# Set the words as the index of the dataframe

# %%
df.set_index('Names')
df
# Out:
#              Names  Character Count  Values
# 0                a                1       1
# 1               aa                2       2
# 2              aal                3      14
# 3            aalii                5      32
# 4              aam                3      15
# ...            ...              ...     ...
# 235880      zythem                6      97
# 235881      Zythia                6      57
# 235882      zythum                6     113
# 235883     Zyzomys                7     117
# 235884  Zyzzogeton               10     147
#
# [235885 rows x 3 columns]

# %% [markdown]
# What is the value of the word 'Acanthomeridae'?

# %%
df.loc[df['Names']=='Acanthomeridae','Values']
# Out:
# 762    85
# Name: Values, dtype: int64

# %%
df.loc[df['Names']=='Acanthomeridae']
# Out:
#               Names  Character Count  Values
# 762  Acanthomeridae               14      85

# %% [markdown]
# What is the highest possible value for a word?

# %%
df.max()
# Out:
# Names              zythum
# Character Count        24
# Values                328
# dtype: object

# %%
df['Values'].max()
# Out:
# 328

# %% [markdown]
# What is the highest possible length of a word

# %%
df['Character Count'].max()
# Out:
# 24

# %% [markdown]
# What is the value of the word with Value '317'

# %%
df.loc[df['Values']==317]
# Out:
#                            Names  Character Count  Values
# 203040  thyroparathyroidectomize               24     317

# %% [markdown]
# What is the most common value?

# %%
df['Values'].mode()
# Out:
# 0    102
# Name: Values, dtype: int64

# %%
df['Character Count'].mode()
# Out:
# 0    9
# Name: Character Count, dtype: int64

# %%
df.value_counts()
# Out:
# Names             Character Count  Values
#                   0                0         2
# polyphote         9                132       1
# polyphyletic      12               166       1
# polyphyletically  16               216       1
# polyphylety       11               179       1
#                                             ..
# embryotrophic     13               167       1
# embryotrophy      12               180       1
# embryous          8                118       1
# embryulcia        10               109       1
# zythum            6                113       1
# Length: 235884, dtype: int64

# %%
df['Values'].value_counts()
# Out:
# 102    2218
# 107    2194
# 100    2185
# 108    2184
# 115    2171
#        ...
# 305       1
# 289       1
# 317       1
# 283       1
# 314       1
# Name: Values, Length: 336, dtype: int64

# %% [markdown]
# What is the shortest word with the value of 107

# %%
df.loc[df['Values']==107].min()
# Out:
# Names              Agriochoerus
# Character Count               5
# Values                      107
# dtype: object

# %% [markdown]
# Create a new column 'Ratio' such that ratio = value/char count

# %%
df['Ratio']=df['Values']/df['Character Count']
df
# Out:
#              Names  Character Count  Values      Ratio
# 0                a                1       1   1.000000
# 1               aa                2       2   1.000000
# 2              aal                3      14   4.666667
# 3            aalii                5      32   6.400000
# 4              aam                3      15   5.000000
# ...            ...              ...     ...        ...
# 235880      zythem                6      97  16.166667
# 235881      Zythia                6      57   9.500000
# 235882      zythum                6     113  18.833333
# 235883     Zyzomys                7     117  16.714286
# 235884  Zyzzogeton               10     147  14.700000
#
# [235885 rows x 4 columns]

# %% [markdown]
# What is the maximum value of ratio?

# %%
df['Ratio'].max()
# Out:
# 26.0

# %% [markdown]
# What is the word with the highest ratio

# %%
df['Ratio'].max()
# Out:
# 26.0

# %%
df.sort_values('Ratio',ascending=False)
# Out:
#         Names  Character Count  Values  Ratio
# 234937      z                1      26   26.0
# 234266      y                1      25   25.0
# 233851  wuzzy                5     121   24.2
# 233881      x                1      24   24.0
# 233852     wy                2      48   24.0
# ...       ...              ...     ...    ...
# 48066       D                1     -28  -28.0
# 28165       C                1     -29  -29.0
# 17095       B                1     -30  -30.0
# 122278                       0       0    NaN
# 128519                       0       0    NaN
#
# [235885 rows x 4 columns]

# %%
df.loc[df['Ratio']==df['Ratio'].max()]
# Out:
#        Names  Character Count  Values  Ratio
# 234937     z                1      26   26.0

# %% [markdown]
# How many words have the ratio of 10

# %%
df.value_counts(df['Ratio']==10)
# Out:
# Ratio
# False    232726
# True       3159
# dtype: int64

# %%
df.loc[df['Ratio']==10]
# Out:
#               Names  Character Count  Values  Ratio
# 7          aardwolf                8      80   10.0
# 31         abaculus                8      80   10.0
# 198        abetment                8      80   10.0
# 329            ably                4      40   10.0
# 403        abounder                8      80   10.0
# ...             ...              ...     ...    ...
# 235406      Zolaist                7      70   10.0
# 235467  zoochemical               11     110   10.0
# 235735     zwieback                8      80   10.0
# 235744    Zygadenus                9      90   10.0
# 235877     Zyrenian                8      80   10.0
#
# [3159 rows x 4 columns]

# %%
df.loc[df['Ratio']==10].count()
# Out:
# Names              3159
# Character Count    3159
# Values             3159
# Ratio              3159
# dtype: int64

# %%
df['Ratio'].value_counts()
# Out:
#  12.000000    4334
#  11.000000    4117
#  13.000000    3716
#  10.000000    3159
#  14.000000    2537
#               ...
# -22.000000       1
# -1.272727        1
# -21.000000       1
# -20.000000       1
#  26.000000       1
# Name: Ratio, Length: 1780, dtype: int64

# %% [markdown]
# What is the maximum value of all words with ratio as 10

# %%
df.loc[df['Ratio']==10].max()
# Out:
# Names              zwieback
# Character Count          21
# Values                  210
# Ratio                  10.0
# dtype: object

# %%
df.query('Ratio==10').max()
# Out:
# Names              zwieback
# Character Count          21
# Values                  210
# Ratio                  10.0
# dtype: object

# %% [markdown]
# Of all the words with the value of 260, what has the loswest character count?

# %%
df.query('Values==260').min()
# Out:
# Names              chromophotolithograph
# Character Count                       17
# Values                               260
# Ratio                          11.818182
# dtype: object

# %%
df.loc[df['Values']==260].min()
# Out:
# Names              chromophotolithograph
# Character Count                       17
# Values                               260
# Ratio                          11.818182
# dtype: object

# %%
# Its describes all values
df.describe()
# Out:
#        Character Count         Values          Ratio
# count    235885.000000  235885.000000  235883.000000
# mean          9.569133     108.969218      11.256517
# std           2.927375      43.525601       2.766208
# min           0.000000     -30.000000     -30.000000
# 25%           8.000000      78.000000       9.846154
# 50%           9.000000     107.000000      11.545455
# 75%          11.000000     137.000000      13.000000
# max          24.000000     328.000000      26.000000
